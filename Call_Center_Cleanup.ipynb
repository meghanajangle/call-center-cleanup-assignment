# %% [markdown]
# # Call Center Cleanup
#
# For this assignment, we will be working with call center data. You can start working on the assignment after the first lesson on Exploratory Data Analysis. Make sure to read the whole assignment before starting anything! As you code along in the Jupyter notebook, you are asked to make note of the results of your analysis. Do so by clicking on the results box and adding your notes beside each question.
#
# ## Business Issue and Understanding
#
# You are working for a company that has two call centers: the North Call Center and the South Call Center. The company is looking to possibly hire five additional reps to enhance customer experience. Your task is to explore how efficient the current reps are in each branch to determine which branch would benefit from additional assistance.
#
# ### How the Call Center Works
#
# Call center representatives are assigned queues. When calls are assigned to a queue, the call is assigned to the next person in line in the queue. After a call is assigned to a representative, the amount of time between assignment and the call starting is divided into busy minutes and not ready minutes. If the call is incoming and a customer is waiting on the phone for a rep, the time is split into three categories: busy minutes, not ready minutes, and incoming call wait time. Once the rep has the customer on the phone, there might be during call wait time, where the call is put on hold while the rep gets an answer for the customer.
#
# ### Notes about the Dataset
#
# If you haven't worked in a call center before, these notes might help you throughout your analysis.
#
# * The call purpose is tagged for each call.
# * The time of the call is tagged in 1 hour blocks starting at 9:00 AM and ending at 5:00 PM.
# * Calls are tagged as incoming or outgoing.
# * Reps are assigned to queues. When the reps are working, they take calls in the order of their queue.
# * A call that is dropped due to technical error or missed by the center because they have reached maximum capacity is a lost call.
# * An abandoned call is when the customer hangs up because they have been waiting for too long.
# * Busy Minutes: the amount of time after a call comes in or needs to go out where the assigned rep is not available because they are busy with other customers.
# * Not Ready Minutes: the amount of time after a call comes in or needs to go out where the assigned rep is not available because they are not ready (for example, getting water).
# * Incoming Wait Time - amount of time after assigned rep is available to take the call customer waits for representative to pick up a call. This is tracked in seconds.
# * During Call Wait Time - amount of time during call that customer has to wait for representative
#
# ## Getting Started
#
# You have two CSVs at your disposal, `NorthCallCenter.csv` and `SouthCallCenter.csv`. Import the appropriate libraries and create two dataframes, one called `north_df` and one called `south_df`.

# %%
# Import the appropriate libraries with aliases
import pandas as pd

# Create two new dataframes
north_df = pd.read_csv("NorthCallCenter.csv")
south_df = pd.read_csv("SouthCallCenter.csv")

# %% [markdown]
# <span style="background-color:orangered; color:orangered;">- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -</span>

# %% [markdown]
# ## Exploratory Data Analysis
#
# Time to do some EDA! In the process of learning more about the two datasets, answer the following questions. In the code blocks below enter the code used to solve the question.  At the end of the section record your answers by double clicking where asked.

# %% [markdown]
# #### EDA Question 1A:  How many reps are in the North branch?

# %%
#Code Used:
no_of_north_reps = north_df["Rep ID"].nunique()
print("No of reps in North Branch:" , no_of_north_reps)
# Out:
# No of reps in North Branch: 9

# %% [markdown]
# #### EDA Question 1B:  How many reps are in the South branch?

# %%
#Code Used:
no_of_south_reps = south_df["Rep ID"].nunique()
print("No of reps in South Branch:" , no_of_south_reps)
# Out:
# No of reps in South Branch: 11

# %% [markdown]
# #### EDA Question 2A:  What is the average busy minutes, not ready minutes, incoming wait time, and during call wait time for the North branch?

# %%
#Code Used:
print("North Center Data:")
print("Average of Busy Minutes:" , round(north_df["Busy Minutes"].mean(),2))
print("Average of Not Ready Minutes:" , round(north_df["Not Ready Minutes"].mean(),2))
print("Average of Incoming Wait Time:" , round(north_df["Incoming Wait Time"].mean(),2))
print("Average of During Call Wait Time:" , round(north_df["During Call Wait Time"].mean(),2))
# Out:
# North Center Data:
# Average of Busy Minutes: 9.99
# Average of Not Ready Minutes: 1.91
# Average of Incoming Wait Time: 3.05
# Average of During Call Wait Time: 2.97

# %% [markdown]
# #### EDA Question 2B:  What is the average busy minutes, not ready minutes, incoming wait time, and during call wait time for the South branch?

# %%
#Code Used:
print("South Center Data:")
print("Average of Busy Minutes:" , round(south_df["Busy Minutes"].mean(),2))
print("Average of Not Ready Minutes:" , round(south_df["Not Ready Minutes"].mean(),2))
print("Average of Incoming Wait Time:" , round(south_df["Incoming Wait Time"].mean(),2))
print("Average of During Call Wait Time:" , round(south_df["During Call Wait Time"].mean(),2))
# Out:
# South Center Data:
# Average of Busy Minutes: 10.05
# Average of Not Ready Minutes: 1.91
# Average of Incoming Wait Time: 3.0
# Average of During Call Wait Time: 3.08

# %% [markdown]
# #### EDA Question 3:  What is the number of calls taken for each time block(Both North and South combined)?

# %%
# Code Used:
print("No of calls taken by both blocks: \n", north_df.groupby(["Time Block"])["Calls"].count() + south_df.groupby(["Time Block"])["Calls"].count())
# Out:
# No of calls taken by both blocks:
#  Time Block
# 10:00 AM     99
# 11:00 AM     56
# 12:00 PM    120
# 1:00 PM      40
# 2:00 PM      65
# 3:00 PM      73
# 4:00 PM      53
# 5:00 PM      43
# 9:00 AM      10
# Name: Calls, dtype: int64

# %% [markdown]
# ##### Record your answers for the EDA section by double clicking here:
# - 1a) Reps in the North Branch = 9
# - 1b) Reps in the South Branch = 11
#
# - 2a) North Branch, (round to the nearest hundredth):
# > - Busy Minutes = 9.99
# > - Not Ready Minutes = 1.91
# > - Incoming Wait Time = 3.05
# > - During Call Wait Time = 2.97
# - 2b) South Branch, (round to the nearest hundredth):
# > - Busy Minutes = 10.05
# > - Not Ready Minutes = 1.91
# > - Incoming Wait Time = 3.0
# > - During Call Wait Time = 2.97
#
# - 3) Total Calls taken for all branches per time block:
# > - 9:00AM   = 10
# > - 10:00AM  = 99
# > - 11:00AM  = 56
# > - 12:00PM  = 120
# > - 1:00PM   = 40
# > - 2:00PM   = 65
# > - 3:00PM   = 73
# > - 4:00PM   = 53
# > - 5:00PM   = 43

# %% [markdown]
# <span style="background-color:orangered; color:orangered;">- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -</span>

# %% [markdown]
# ## Cleaning Your Data
# Now you need to clean up the datasets. When cleaning the datasets, you may find that there isn't dirty data to clean. That is okay! Some questions you need to answer about the data sets.
# * Add additional code blocks as needed to show how you came to your conclusions. Add comments in your code blocks to help others understand your thinking.

# %% [markdown]
# #### Cleaning Question 1:  Is there any missing data and if yes explain what you would do with the missing data and why?
# ##### Record your answer by double clicking here:
# > Your Answer:
#
# North Call center ->
# 1. Has missing values only for Incoming wait time - around 67% of records are missing. This is record of amount of time after assigned rep is available to take the call customer waits for representative to pick up a call.
#
# Action:
# All the missing data is for Outgoing calls which in this case can be updated with "0" as not applicable
#
# South Call center ->
# 1. Has missing values only for Incoming wait time - around 60% of records are missing. This is record of amount of time after assigned rep is available to take the call customer waits for representative to pick up a call.
#
# Action:
# All the missing data is for Outgoing calls which in this case can be updated with "0" as not applicable

# %%
# Code Used
for col in north_df.columns:
   missing_percentage = np.mean(north_df[col].isnull())
   print('{} - {}%'.format(col, round(missing_percentage*100)))
# Out:
# Unnamed: 0 - 0%
# Branch - 0%
# Call Purpose - 0%
# Time Block - 0%
# Incoming or Outgoing - 0%
# Queue - 0%
# Rep ID - 0%
# Sale - 0%
# Lost Call - 0%
# Abandoned - 0%
# Busy Minutes - 0%
# Not Ready Minutes - 0%
# Incoming Wait Time - 67%
# During Call Wait Time - 0%
# Calls - 0%

# %%
for col in south_df.columns:
   missing_percentage = np.mean(south_df[col].isnull())
   print('{} - {}%'.format(col, round(missing_percentage*100)))
# Out:
# Unnamed: 0 - 0%
# Branch - 0%
# Call Purpose - 0%
# Time Block - 0%
# Incoming or Outgoing - 0%
# Queue - 0%
# Rep ID - 0%
# Sale - 0%
# Lost Call - 0%
# Abandoned - 0%
# Busy Minutes - 0%
# Not Ready Minutes - 0%
# Incoming Wait Time - 60%
# During Call Wait Time - 0%
# Calls - 0%

# %%
#Update Null Values with NA
north_df["Incoming Wait Time"] = north_df["Incoming Wait Time"].fillna(0)
north_df.info()

south_df["Incoming Wait Time"] = south_df["Incoming Wait Time"].fillna(0)
south_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245 entries, 0 to 244
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             245 non-null    int64
#  1   Branch                 245 non-null    object
#  2   Call Purpose           245 non-null    object
#  3   Time Block             245 non-null    object
#  4   Incoming or Outgoing   245 non-null    object
#  5   Queue                  245 non-null    object
#  6   Rep ID                 245 non-null    object
#  7   Sale                   245 non-null    object
#  8   Lost Call              245 non-null    int64
#  9   Abandoned              245 non-null    int64
#  10  Busy Minutes           245 non-null    int64
#  11  Not Ready Minutes      245 non-null    int64
#  12  Incoming Wait Time     245 non-null    float64
#  13  During Call Wait Time  245 non-null    int64
# ...

# %% [markdown]
# #### Cleaning Question 2:  In the North data set, there are two separate "YES" values for a sale. Why and how did you rectify the issue?
# ##### Record your answer by double clicking here:
# > Your Answer:
# Looks like the sale field was updated for an abandoned call. This might be a mistyped entry in the sales field as Abandoned calls are ended by Users if they are waiting for a long time for a response and assumption is that the sales may not happen for abandoned calls. I will be dropping these 2 records as I dont have a way to validate this information at this time.

# %%
#Code Used

# Drop row using index value
north_df = north_df.drop(86)
north_df = north_df.drop(87)

north_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 243 entries, 0 to 244
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             243 non-null    int64
#  1   Branch                 243 non-null    object
#  2   Call Purpose           243 non-null    object
#  3   Time Block             243 non-null    object
#  4   Incoming or Outgoing   243 non-null    object
#  5   Queue                  243 non-null    object
#  6   Rep ID                 243 non-null    object
#  7   Sale                   243 non-null    object
#  8   Lost Call              243 non-null    int64
#  9   Abandoned              243 non-null    int64
#  10  Busy Minutes           243 non-null    int64
#  11  Not Ready Minutes      243 non-null    int64
#  12  Incoming Wait Time     243 non-null    float64
#  13  During Call Wait Time  243 non-null    int64
# ...

# %% [markdown]
# #### Cleaning Question 3:  Are there duplicates in the two data sets? If there are, how did you handle them?
# ##### Record your answer by double clicking here:
# > Your Answer: No Duplicate records found in both North Data Center and South Data Center

# %%
#Code Used

# Find duplicates for North Data Center 
north_df_duplicates = north_df[north_df.duplicated()]
 
print("North Call Center Duplicate Rows :\n" , north_df_duplicates.count())
# Out:
# North Call Center Duplicate Rows :
#  Unnamed: 0               0
# Branch                   0
# Call Purpose             0
# Time Block               0
# Incoming or Outgoing     0
# Queue                    0
# Rep ID                   0
# Sale                     0
# Lost Call                0
# Abandoned                0
# Busy Minutes             0
# Not Ready Minutes        0
# Incoming Wait Time       0
# During Call Wait Time    0
# Calls                    0
# dtype: int64

# %%
#Code Used


# Find duplicates for South Data Center 
south_df_duplicates = south_df[south_df.duplicated()]

print("South Call Center Duplicate Rows :\n", south_df_duplicates.count())
# Out:
# South Call Center Duplicate Rows :
#  Unnamed: 0               0
# Branch                   0
# Call Purpose             0
# Time Block               0
# Incoming or Outgoing     0
# Queue                    0
# Rep ID                   0
# Sale                     0
# Lost Call                0
# Abandoned                0
# Busy Minutes             0
# Not Ready Minutes        0
# Incoming Wait Time       0
# During Call Wait Time    0
# Calls                    0
# dtype: int64

# %% [markdown]
# #### Cleaning Question 4:  Is any of the data in the two data sets unnecessary? If yes, how did you handle it?
# ##### Record your answer by double clicking here:
#
# > Your Answer:
#
# No Unnecessary data identified in data sets.

# %%
#Code Used

# Box Plot to check any outliers
north_df.boxplot()
# Out:
# <AxesSubplot:>

# %%
#Code Used
south_df.boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# <span style="background-color:orangered; color:orangered;">- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -</span>

# %% [markdown]
# ## Data Manipulation
# Before you begin answering any questions, combine the two datasets together to create a third dataframe called df. You can use this third dataframe to compare the two call centers to company-wide trends.
# * Add additional code blocks as needed to show how you came to your conclusions. Add comments in your code blocks to help others understand your thinking. Record your answer by double clicking the below cell.

# %%
# Create dataframe for the entire company named df

#Appening both the data frames into one data frame for analyzing company based data.
df = north_df.append(south_df, ignore_index = True)

#Check details of the new data frame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 557 entries, 0 to 556
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             557 non-null    int64
#  1   Branch                 557 non-null    object
#  2   Call Purpose           557 non-null    object
#  3   Time Block             557 non-null    object
#  4   Incoming or Outgoing   557 non-null    object
#  5   Queue                  557 non-null    object
#  6   Rep ID                 557 non-null    object
#  7   Sale                   557 non-null    object
#  8   Lost Call              557 non-null    int64
#  9   Abandoned              557 non-null    int64
#  10  Busy Minutes           557 non-null    int64
#  11  Not Ready Minutes      557 non-null    int64
#  12  Incoming Wait Time     557 non-null    float64
#  13  During Call Wait Time  557 non-null    int64
# ...

# %% [markdown]
# #### Manipulation Question 1:  Group by Rep ID and sum the resulting structure. Sort by calls to determine which rep in each branch has the highest number of calls.
#
# ##### Record your answer by double clicking here:
# Rep with the hightest number of calls and their total calls:
# - North Branch = Brent (37)
# - South Branch = Eric (35)

# %%
# Code Used
print("\nRep and their total calls:")

# Using group by and agg function to get the highest number of calls per Branch and sorting them in descending
df.groupby(['Branch', 'Rep ID']).agg({'Calls' : 'count'} , skipna = True).sort_values(["Calls"], ascending = False)
# Out:
# Rep and their total calls:
#                Calls
# Branch Rep ID
# North  Brent      37
# South  Eric       35
#        Randy      33
#        Sandy      32
#        Helga      31
# North  Duke       29
#        Todd       29
# South  Kate       29
#        George     29
# North  Lilly      28
# South  Karl       28
#        Josh       26
#        Susan      26
# North  Joe        26
# South  Sharon     25
# North  Xander     24
#        Cam        24
#        Andy       23
#        Amanda     23
# South  Alice      20

# %% [markdown]
# #### Manipulation Question 2:  The average call abandonment rate is a KPI when it comes to determining call center efficiency. As you may recall, abandoned calls are calls where the customer hangs up due to long call times. What is the average call abandonment rate for each branch and the whole company? Do any of these fall out of the optimal range of 2-5%?
# ##### Record your answer by double clicking here:
# Average Call Abandonment Rates (round to the nearest hundredth):
# - North Branch = 2.0
# - South Branch = 1.0
# - Company Wide = 2.0
# - Do any of these fall out of the optimal range of 2-5%? South Branch has 1% Abandonment rate which is better than Optimal range.

# %%
# Code Used

#Using groupby and mean function get the Abandonment rate
print("Branch wise Average Call Abandonment Rates:\n",  round(df.groupby(["Branch"])["Abandoned"].mean(),2) * 100)
print("Company wide Average Call Abandonment Rates:", round(df["Abandoned"].mean(),2) * 100)
# Out:
# Branch wise Average Call Abandonment Rates:
#  Branch
# North    2.0
# South    1.0
# Name: Abandoned, dtype: float64
# Company wide Average Call Abandonment Rates: 2.0

# %% [markdown]
# #### Manipulation Question 3:  Service level is another KPI when it comes to measuring call center efficiency. Service level is the percentage of calls answered within a specific number of seconds. In the case of your employer, their ideal time frame is 2 seconds. What is the percentage of calls answered within 2 seconds for each branch and the entire company?
# ##### Record your answer by double clicking here:
# Percentage of calls answered within 2 seconds, include # of calls:
# - North Branch = 40% (33 Calls)
# - South Branch = 38% (48 Calls)
# - Company Wide = 39% (81 Calls)

# %%
# Code Used
#Assumption - Incoming Wait time is recorded in seconds - IF in minutes then the anlysis will change and there will be no call 
#picked within 2 seconds, in that case Service Level will be 0%

# Filtering the records with wait time less than equal to 2 seconds into new dataset for North and calls = incoming
# only incoming calls are applicable for this KPI
north_df_waittime = north_df[north_df["Incoming Wait Time"] <= 2.0]
north_df_waittime = north_df_waittime[north_df_waittime["Incoming or Outgoing"] == "Incoming"]
north_df_total_incoming = north_df[north_df["Incoming or Outgoing"] == "Incoming"]

# Filtering the records with wait time less than equal to 2 seconds into new dataset for South and calls = incoming
# only incoming calls are applicable for this KPI
south_df_waittime = south_df[south_df["Incoming Wait Time"] <= 2.0]
south_df_waittime = south_df_waittime[south_df_waittime["Incoming or Outgoing"] == "Incoming"]
south_df_total_incoming = south_df[south_df["Incoming or Outgoing"] == "Incoming"]

# Filtering the records with wait time less than equal to 2 seconds into new dataset for entire company and calls = incoming
# only incoming calls are applicable for this KPI
df_waitime = df[df["Incoming Wait Time"] <= 2.0]
df_waittime = df_waittime[df_waittime["Incoming or Outgoing"] == "Incoming"]
df_total_incoming = df[df["Incoming or Outgoing"] == "Incoming"]


print("North Branch Service Level:")
print("Percentage of calls answered within 2 seconds: \n", round(north_df_waittime["Incoming Wait Time"].count() / north_df_total_incoming["Incoming Wait Time"].count() * 100))
print("No of calls answered within 2 seconds:\n", round(north_df_waittime["Incoming Wait Time"].count()))

print("\nSouth Branch Service Level:")
print("Percentage of calls answered within 2 seconds: \n", round(south_df_waittime["Incoming Wait Time"].count() / south_df_total_incoming["Incoming Wait Time"].count() * 100))
print("No of calls answered within 2 seconds:\n", round(south_df_waittime["Incoming Wait Time"].count()))


print("\nCompany Wide Service Level:")
print("Percentage of calls answered within 2 seconds: \n", round(df_waittime["Incoming Wait Time"].count() / df_total_incoming["Incoming Wait Time"].count() * 100))
print("No of calls answered within 2 seconds:\n", round(df_waittime["Incoming Wait Time"].count()))
# Out:
# North Branch Service Level:
# Percentage of calls answered within 2 seconds:
#  40
# No of calls answered within 2 seconds:
#  33
#
# South Branch Service Level:
# Percentage of calls answered within 2 seconds:
#  38
# No of calls answered within 2 seconds:
#  48
#
# Company Wide Service Level:
# Percentage of calls answered within 2 seconds:
#  39
# No of calls answered within 2 seconds:
#  81

# %% [markdown]
# #### Manipulation Question 4: For each branch and the entire company, what is the average speed of answer?
# ##### Record your answer by double clicking here:
# Average speed of answer (rounded to nearest hundredth):
# - North Branch in seconds = 3.05
# - South Branch in seconds = 3.00
# - Company Wide in seconds = 3.02

# %%
# Code Used 
#Using groupby and mean function get the Average Speed to answer 

print("Branch wise average speed of answer:\n",  round(df_total_incoming.groupby(["Branch"])["Incoming Wait Time"].mean(), 2))
print("Company wide average speed of answer:", round(df_total_incoming["Incoming Wait Time"].mean(), 2))
# Out:
# Branch wise average speed of answer:
#  Branch
# North    3.05
# South    3.00
# Name: Incoming Wait Time, dtype: float64
# Company wide average speed of answer: 3.02

# %% [markdown]
# <span style="background-color:orangered; color:orangered;">- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -</span>

# %% [markdown]
# ## Visualization
#
# Create a visualization for each of the following questions. Some of the code to handle aggregating and storing data may be written for you. For each visualization, you choose the chart style that you feel suits the situation best. Make note of the chart style you chose and why.
#
# *NOTE Some questions you may decide to use more than one chart and or chart style.

# %% [markdown]
# #### Visualization 1:  What is the average abandonment rate per queue?
# ##### Record your answer by double clicking here:
#
# > Chart style you chose and why: Line chart provide a simplistic view to see abandonment rates for different queues. It shows trend between different queues and is also easy to compare to see how each queue performed.

# %%
# Create visualization 1 here
# Import any additional libraries needed with alias
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
from matplotlib import style


# The dictionary abandonment_rates has the data you need.
abandonment_rates = {}
queues = ["A", "B", "C", "D"]
queue_dict = df.groupby("Queue").agg("sum")
for i in range(4):
    abandonment_rates[queues[i]] = queue_dict["Abandoned"][i] / queue_dict["Calls"][i] 

#Your Code Here:
# Setting the graph style and template
style.use("Solarize_Light2")
plt.rcParams['figure.figsize'] = (15,5)

#Creating DF from dictonary
abandonment_rates_df = pd.DataFrame(abandonment_rates.items(), index = queues)

# Line chart Parameters
visual1 = abandonment_rates_df.plot(kind = 'line', color = 'r')
plt.title('Abandonment Rates per Queue',color = 'black')
plt.xlabel('Queue',color = 'black')
plt.ylabel('Abandonment Rate',color = 'black')
plt.xticks(color = 'black')
plt.yticks(color = 'black')
plt.savefig('linechart_single.png')

plt.show()

# %% [markdown]
# #### Visualization 2: What is the service level percentage and average speed of answer for each rep in the North Branch?
# ##### Record your answer by double clicking here:
#
# > Chart style you chose and why:
# Average Speed of Answer of each Rep KPI - Used Horizontal Chart as it provides good view to look at the performance of each Rep. Line chart and Vertical Bar chart would also provide similar views as these charts provide stakeholders a view to compare and review performance for each Reps.
# Service level KPI - Same as above, but in this case I have used Vertical bar just to show the similarities between different charts but also at the same time shows its effectiviness in viewing the data.

# %%
# Create visualization 2 here
# north_plt contains the data you need for the average speed of answer of each rep

north_plt = north_df_waittime_all.groupby("Rep ID")["Incoming Wait Time"].mean().to_frame().reset_index()


# Finding each Rep's Personal Service Level Percentage.  Basically, Calls within 2 secs / total calls

# Table 1: Total Incoming calls less than 2 seconds grouped by Rep
quick_calls = north_df_waittime_all[north_df_waittime_all["Incoming Wait Time"] <= 2.0]
quick_reps = quick_calls[["Rep ID", "Calls"]]
quick_stats = quick_reps.groupby(["Rep ID"]).sum()  # Final Table


# Table 2: Total Incoming Calls Only grouped by Rep
total_calls_in = north_df_waittime_all[north_df_waittime_all["Incoming or Outgoing"] == "Incoming"]
rep_calls = total_calls_in[["Rep ID", "Calls"]]     
total_stats = rep_calls.groupby(["Rep ID"]).sum() # Final Table  

#  Table 3: Service Level Percentage created via merge
service_level = pd.merge(quick_stats, total_stats, on="Rep ID")

# Create Percentage Column in Table 3
service_level["Service Level %"] = service_level["Calls_x"]/service_level["Calls_y"] * 100

#Your Code Here:

#Average Speed of Answer KPI Chart - Horizontal Bar

#Setting Index
north_plt = north_plt.set_index("Rep ID")

# Sorting by descneding for better view of performance per Rep ID
north_plt = north_plt.sort_values(["Incoming Wait Time"], ascending = False)

# Chart Parameters
style.use('ggplot')
north_plt.plot.barh(legend = False, color = 'green', edgecolor = 'black')
plt.title('Average speed of Answer by Rep for North Branch',color = 'black')
plt.xlabel('RepID',color = 'black')
plt.ylabel('Average speed',color = 'black')
plt.xticks(color = 'black')
plt.yticks(color = 'black')
plt.savefig('bar_horizontal.png')

plt.show()

#Service Level KPI - Vertical Bar Chart
service_level_kpi = service_level.drop(["Calls_x" , "Calls_y"], axis = 1)
service_level_kpi = service_level_kpi.sort_values(["Service Level %"], ascending = False)

# Chart Parameters
style.use('tableau-colorblind10')
service_level_kpi.plot(kind = 'bar', legend = False)
plt.title('Service Level KPI for North Branch',color = 'black')
plt.xticks(color = 'black')
plt.yticks(color = 'black')
plt.ylabel('Service Level',color = 'black')
plt.xlabel('Rep ID',color = 'black')
plt.savefig('bar_vertical.png')

plt.show()

# %% [markdown]
# #### Visualization 3: For each type of call purpose, how many calls are outgoing vs. incoming?
# ##### Record your answer by double clicking here:
#
# Calls per call purpose:
#
# Complaint        Incoming                 51
#
# Product Support  Outgoing                228
#                  Incoming                 82
#
# Sales Support    Outgoing                121
#                  Incoming                 75
#
# > Chart style you chose and why:
# I have used the Donut chart to view this KPI as it is a good chart to show percentage split between incoming and outgoing calls and it also gives a nice view to see what kind of calls(Incoming or Outgoing) are dominating for each call purpose.

# %%
# Create visualization 3 here:
# The three dictionaries, complaints, sales_support, and product_support, have the information you need

purpose_group = df.groupby("Call Purpose")
call_purpose = ["Complaint", "Product Support", "Sales Support"]
purpose_counts = purpose_group["Incoming or Outgoing"].value_counts()
print(purpose_counts)

complaints = purpose_counts["Complaint"].to_dict()
sales_support = purpose_counts["Sales Support"].to_dict()
product_support = purpose_counts["Product Support"].to_dict()

#Your Code Here:
#Creating DF from dictonary for Complaints
complaints_df = pd.DataFrame(complaints.items(), index = ["Incoming"])
complaints_df.rename(columns = {0:'Type', 1:'Total'}, inplace = True)
complaints_df = complaints_df.drop(["Type"], axis = 1)

# Donut Chart Parameters
circle = plt.Circle( (0,0), 0.7, color='white')
colors = ['green']
plt.pie(complaints_df["Total"], autopct = '%1.1f%%', shadow = False, explode = [0], colors = colors, startangle = 90)
fig = plt.gcf()
fig.gca().add_artist(circle)
plt.legend(complaints_df.index, fontsize = 12, loc = 'upper left')
plt.title('Complaints - Outgoing vs Incoming Ratio', color = 'black', fontsize = 18)
plt.axis('equal')
plt.savefig('doughnut.png')

plt.show()

#Creating DF from dictonary for Sales Support
sales_support_df = pd.DataFrame(sales_support.items(), index = ["Outgoing" , "Incoming"])
sales_support_df.rename(columns = {0:'Type', 1:'Total'}, inplace = True)
sales_support_df = sales_support_df.drop(["Type"], axis = 1)

# Donut Chart Parameters
circle = plt.Circle( (0,0), 0.7, color='white')
colors = ['blue', 'green']
plt.pie(sales_support_df["Total"], autopct = '%1.1f%%', shadow = False, explode = [0,0], colors = colors, startangle = 0)
fig = plt.gcf()
fig.gca().add_artist(circle)
plt.legend(sales_support_df.index, fontsize = 12, loc = 'upper left')
plt.title('Sales Support - Outgoing vs Incoming Ratio', color = 'black', fontsize = 18)
plt.axis('equal')
plt.savefig('doughnut.png')

plt.show()

#Creating DF from dictonary for Product Support
product_support_df = pd.DataFrame(product_support.items(), index = ["Outgoing" , "Incoming"])
product_support_df.rename(columns = {0:'Type', 1:'Total'}, inplace = True)
product_support_df = product_support_df.drop(["Type"], axis = 1)

# Donut Chart Parameters
circle = plt.Circle( (0,0), 0.7, color='white')
colors = ['blue', 'green']
plt.pie(product_support_df["Total"], autopct = '%1.1f%%', shadow = False, explode = [0,0], colors = colors, startangle = 0)
fig = plt.gcf()
fig.gca().add_artist(circle)
plt.legend(product_support_df.index, fontsize = 12, loc = 'upper left')
plt.title('Product Support - Outgoing vs Incoming Ratio', color = 'black', fontsize = 18)
plt.axis('equal')
plt.savefig('doughnut.png')

plt.show()
# Out:
# Call Purpose     Incoming or Outgoing
# Complaint        Incoming                 51
# Product Support  Outgoing                228
#                  Incoming                 82
# Sales Support    Outgoing                121
#                  Incoming                 75
# Name: Incoming or Outgoing, dtype: int64

# %% [markdown]
# <span style="background-color:orangered; color:orangered;">- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -</span>

# %% [markdown]
# ## Summarize Your Work
#
# With what you know now about the two call centers and the entire company, answer the following questions. Note that while this is subjective, you should include relevant data to back up your opinion.

# %% [markdown]
# #### Summary Question 1:  Using KPIs such as average abandonment rate, service level and average speed of answer, in your opinion, which one of the two branches is operating more efficiently? Why?
#
# ##### Record your answer by double clicking here:
# > Your Answer:
# Based on the different KPIs produced, South Branch is performing more efficiently compared to North Branch.
# Following are some of the key points from the KPI.
# South Branch had 1% Abandonment rate which is better than the optimal range of 2-5%, Service Level and even though at the service level KPI, South Branch is 38% compared to 40% to North Branch, South Branch has taken more calls compared to North and their Average speed to answer for all incoming calls is 3.00 bette than North Branch.

# %% [markdown]
# #### Summary Question 2: Based on the number of reps in each branch and how quickly the reps are working, in your opinion, which branch would benefit from the extra help?
#
# ##### Record your answer by double clicking here:
# > Your Answer:
# North Branch can use the extra help as they are already lower in numbers compared to South Branch. This will also improve their perfromance in speed of answer and abandonment rate KPIs.

# %% [markdown]
# #### Summary Question 3: Now that you have explored the datasets, is there any data or information that you wish you had in this analysis?
#
# ##### Record your answer by double clicking here:
# > Your Answer: Datasets seems to be providing all the information needed to calculate the current KPIs but may be in order to improve Company's performance, we could also see the customer details like are same customers calling about Complaints, product support or sales? what region are they calling from, does the company have more products sales in one region compared to other. This data may help to know if help is needed for one branch compared to other.

# %% [markdown]
# <span style="background-color:orangered; color:orangered;">- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -</span>

# %% [markdown]
# ## Bonus Mission
# Create a visualization that answers this question: For each call purpose, how many calls (incoming and outgoing) take place in each time block?
# ##### Record your answer by double clicking here:
# No of calls per time block are shown in the area chart below.
# > Chart style you chose and why:
# Used Area chart to view this KPI as it shows good view to show how busy each block was for each call purpose.

# %%
# Create your Bonus Mission visualization here!
call_times = df[["Time Block", "Call Purpose", "Incoming or Outgoing", "Calls"]]

# Use groupby to plot based on time blocks:
call_times_block = call_times.groupby(["Time Block"]).sum(["Calls"])

# stacked area chart
color = ['skyblue','blue']
call_times_block.plot(kind = 'area', stacked = False, color = color)
plt.title('Calls per Time Block for all call purpose',color = 'black')
plt.legend(fontsize = 12, labelcolor = 'black')
plt.xlabel('Time Block',color = 'black')
plt.ylabel('Number of Calls',color = 'black')
plt.xticks(color = 'black')
plt.yticks(color = 'black')
plt.savefig('area_stacked.png')

plt.show()

# Use groupby and get_group to select which call purpose to plot:

# %%
call_times_purpose = call_times.groupby(["Call Purpose"])

# extract keys from groups
keys = call_times_purpose.groups.keys()
 
for i in keys:
    
    call_times_group_df = call_times_purpose.get_group(i)


    # Use groupby to plot based on time blocks:
    call_times_group_df_summary = call_times_group_df.groupby(["Time Block"]).sum(["Calls"])

    # stacked area chart
    color = ['skyblue','blue']
    call_times_group_df_summary.plot(kind = 'area', stacked = False, color = color)
    title = i + '- Calls per Time Block'
    plt.title(title, color = 'black')
    plt.legend(fontsize = 12, labelcolor = 'black')
    plt.xlabel('Time Block',color = 'black')
    ylabel = "Number of Calls for " + i
    plt.ylabel(ylabel,color = 'black')
    plt.xticks(color = 'black')
    plt.yticks(color = 'black')
    plt.savefig('area_stacked.png')

    plt.show()
